# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    
    title: str
    outline: str
    content: str
    evaluate: str

# %%
def create_outline(state: BlogState) -> BlogState:
    ## Fetch title
    title = state['title']
    
    ## call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    
    ## update state
    state['outline'] = outline
    
    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    
    title = state['title']
    outline = state['outline']
    
    prompt = f'Write a detailed blig on the title - {title} using the following outline \n {outline}'
    content = model.invoke(prompt).content
    
    state['content'] = content
    
    return state

# %%
def evaluate_blog(state: BlogState) -> BlogState:
    outline = state['outline']
    content = state['content']
    
    prompt = f'Based on the outline evaluate this blog generated by AI. Give feedback \n Outline: {outline} \n\n Blog Generated: {content}'
    evaluation = model.invoke(prompt).content
    
    state['evaluate'] = evaluation
    
    return state

# %%
graph = StateGraph(BlogState)

## nodes

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)
graph.add_node('evaluate_blog', evaluate_blog)

## edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', 'evaluate_blog')
graph.add_edge('evaluate_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': "Rise of AI in Pakistan"}

final_state = workflow.invoke(initial_state)

# %%
final_state
# Out:
# {'title': 'Rise of AI in Pakistan',
#  'outline': "I. Introduction\n    A. Brief explanation of AI\n    B. Context of AI development in Pakistan\n    C. Purpose of the blog\n\nII. Background of AI in Pakistan\n    A. Timeline of AI development in Pakistan\n    B. Key players in AI research and development in Pakistan\n    C. Government initiatives to promote AI technology\n\nIII. Current Applications of AI in Pakistan\n    A. Healthcare\n        1. AI-assisted diagnostics\n        2. Drug discovery\n    B. Agriculture\n        1. Crop monitoring\n        2. Pest detection\n    C. Finance\n        1. Fraud detection\n        2. Algorithmic trading\n    D. Education\n        1. Personalized learning\n        2. Virtual classrooms\n\nIV. Challenges and Opportunities\n    A. Lack of skilled AI professionals\n    B. Ethical concerns\n    C. Economic benefits of AI adoption\n    D. Opportunities for AI growth in Pakistan\n\nV. Future Prospects of AI in Pakistan\n    A. Potential applications in various industries\n    B. Investment opportunities in AI startups\n    C. Role of academia in AI research and development\n\nVI. Conclusion\n    A. Recap of key points\n    B. Significance of AI in shaping Pakistan's future\n    C. Call to action for further exploration and involvement in AI in Pakistan.",
#  'content': "I. Introduction\n\nA. Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, such as learning, reasoning, and self-correction. It has the potential to revolutionize various industries by automating tasks, improving efficiency, and driving innovation. \n\nB. In recent years, Pakistan has seen a rise in AI development, with various startups and organizations working on cutting-edge technologies. \n\nC. The purpose of this blog is to provide an overview of the current landscape of AI in Pakistan, including its history, applications, challenges, and future prospects.\n\nII. Background of AI in Pakistan\n\nA. The development of AI in Pakistan can be traced back to the early 2000s when academic institutions started conducting research in the field. \n\nB. Key players in AI research and development in Pakistan include entities such as the National University of Sciences and Technology (NUST), Lahore University of Management Sciences (LUMS), and Karachi Institute of Economics and Technology (KIET).\n\nC. The government has also taken initiatives to promote AI technology in Pakistan, such as launching programs to fund research projects and organizing conferences and workshops to raise awareness about AI.\n\nIII. Current Applications of AI in Pakistan\n\nA. In the healthcare sector, AI is being used for tasks such as assisting in diagnostics and drug discovery.\n\nB. In agriculture, AI is being applied for crop monitoring and pest detection, helping farmers improve their crop yields.\n\nC. In finance, AI is being used for fraud detection and algorithmic trading, enabling companies to make better-informed decisions.\n\nD. In education, AI is being used for personalized learning and virtual classrooms, enhancing the learning experience for students.\n\nIV. Challenges and Opportunities\n\nA. One of the main challenges in Pakistan is the lack of skilled AI professionals, which hinders the adoption of AI technologies.\n\nB. Ethical concerns surrounding AI, such as data privacy and bias in algorithms, need to be addressed to ensure responsible usage of the technology.\n\nC. Despite these challenges, there are significant economic benefits to be gained from the adoption of AI, such as increased productivity and efficiency.\n\nD. There are ample opportunities for AI growth in Pakistan, with the potential to transform industries and create new job opportunities.\n\nV. Future Prospects of AI in Pakistan\n\nA. AI has the potential to be applied in various industries in Pakistan, such as healthcare, finance, agriculture, and education, leading to increased efficiency and innovation.\n\nB. There are investment opportunities in AI startups in Pakistan, with investors looking to capitalize on the growing market for AI technologies.\n\nC. Academia plays a crucial role in AI research and development, with universities and research institutions collaborating with industry partners to drive innovation.\n\nVI. Conclusion\n\nA. In conclusion, the rise of AI in Pakistan holds great promise for the future, with the potential to transform industries and drive economic growth.\n\nB. AI has the power to shape Pakistan's future by driving innovation, creating new job opportunities, and improving the quality of life for its citizens.\n\nC. We encourage readers to explore and get involved in the field of AI in Pakistan, as it presents exciting opportunities for growth and development.",
#  'evaluate': "Overall, the blog generated by AI follows a structured outline and provides a comprehensive overview of the current landscape of AI in Pakistan. It covers various aspects such as the background of AI development in Pakistan, current applications in different sectors, challenges and opportunities, future prospects, and a call to action for further exploration and involvement in AI.\n\nHowever, the blog could benefit from some improvements in terms of depth and originality. The content provided is quite general and lacks specific examples, case studies, or interviews that could make it more engaging and informative for readers. Additionally, while the blog briefly mentions the key players in AI research and development in Pakistan, it could elaborate more on their specific contributions and achievements in the field.\n\nFurthermore, the conclusion could be strengthened by providing more concrete examples of how AI is already shaping Pakistan's future and how individuals can get involved in the field beyond just exploration. Suggestions for further reading, resources, or upcoming events related to AI in Pakistan could also enhance the call to action.\n\nOverall, while the blog provides a good overview of the topic, enhancing the depth of content, providing specific examples, and offering more actionable steps for readers could make it more engaging and impactful."}

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief explanation of AI
#     B. Context of AI development in Pakistan
#     C. Purpose of the blog
#
# II. Background of AI in Pakistan
#     A. Timeline of AI development in Pakistan
#     B. Key players in AI research and development in Pakistan
#     C. Government initiatives to promote AI technology
#
# III. Current Applications of AI in Pakistan
#     A. Healthcare
#         1. AI-assisted diagnostics
#         2. Drug discovery
#     B. Agriculture
#         1. Crop monitoring
#         2. Pest detection
#     C. Finance
#         1. Fraud detection
#         2. Algorithmic trading
#     D. Education
#         1. Personalized learning
#         2. Virtual classrooms
#
# IV. Challenges and Opportunities
#     A. Lack of skilled AI professionals
#     B. Ethical concerns
#     C. Economic benefits of AI adoption
#     D. Opportunities for AI growth in Pakistan
#
# V. Future Prospects of AI in Pakistan
#     A. Potential applications in various industries
#     B. Investment opportunities in AI startups
#     C. Role of academia in AI research and development
#
# VI. Conclusion
#     A. Recap of key points
#     B. Significance of AI in shaping Pakistan's future
#     C. Call to action for further exploration and involvement in AI in Pakistan.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, such as learning, reasoning, and self-correction. It has the potential to revolutionize various industries by automating tasks, improving efficiency, and driving innovation.
#
# B. In recent years, Pakistan has seen a rise in AI development, with various startups and organizations working on cutting-edge technologies.
#
# C. The purpose of this blog is to provide an overview of the current landscape of AI in Pakistan, including its history, applications, challenges, and future prospects.
#
# II. Background of AI in Pakistan
#
# A. The development of AI in Pakistan can be traced back to the early 2000s when academic institutions started conducting research in the field.
#
# B. Key players in AI research and development in Pakistan include entities such as the National University of Sciences and Technology (NUST), Lahore University of Management Sciences (LUMS), and Karachi Institute of Economics and Technology (KIET).
#
# C. The government has also taken initiatives to promote AI technology in Pakistan, such as launching programs to fund research projects and organizing conferences and workshops to raise awareness about AI.
#
# III. Current Applications of AI in Pakistan
#
# A. In the healthcare sector, AI is being used for tasks such as assisting in diagnostics and drug discovery.
#
# B. In agriculture, AI is being applied for crop monitoring and pest detection, helping farmers improve their crop yields.
#
# C. In finance, AI is being used for fraud detection and algorithmic trading, enabling companies to make better-informed decisions.
#
# D. In education, AI is being used for personalized learning and virtual classrooms, enhancing the learning experience for students.
#
# IV. Challenges and Opportunities
#
# A. One of the main challenges in Pakistan is the lack of skilled AI professionals, which hinders the adoption of AI technologies.
#
# B. Ethical concerns surrounding AI, such as data privacy and bias in algorithms, need to be addressed to ensure responsible usage of the technology.
#
# C. Despite these challenges, there are significant economic benefits to be gained from the adoption of AI, such as increased productivity and efficiency.
#
# D. There are ample opportunities for AI growth in Pakistan, with the potential to transform industries and create new job opportunities.
#
# V. Future Prospects of AI in Pakistan
#
# A. AI has the potential to be applied in various industries in Pakistan, such as healthcare, finance, agriculture, and education, leading to increased efficiency and innovation.
#
# B. There are investment opportunities in AI startups in Pakistan, with investors looking to capitalize on the growing market for AI technologies.
#
# C. Academia plays a crucial role in AI research and development, with universities and research institutions collaborating with industry partners to drive innovation.
#
# VI. Conclusion
#
# A. In conclusion, the rise of AI in Pakistan holds great promise for the future, with the potential to transform industries and drive economic growth.
#
# B. AI has the power to shape Pakistan's future by driving innovation, creating new job opportunities, and improving the quality of life for its citizens.
#
# C. We encourage readers to explore and get involved in the field of AI in Pakistan, as it presents exciting opportunities for growth and development.

# %%
print(final_state['evaluate'])
# Out:
# Overall, the blog generated by AI follows a structured outline and provides a comprehensive overview of the current landscape of AI in Pakistan. It covers various aspects such as the background of AI development in Pakistan, current applications in different sectors, challenges and opportunities, future prospects, and a call to action for further exploration and involvement in AI.
#
# However, the blog could benefit from some improvements in terms of depth and originality. The content provided is quite general and lacks specific examples, case studies, or interviews that could make it more engaging and informative for readers. Additionally, while the blog briefly mentions the key players in AI research and development in Pakistan, it could elaborate more on their specific contributions and achievements in the field.
#
# Furthermore, the conclusion could be strengthened by providing more concrete examples of how AI is already shaping Pakistan's future and how individuals can get involved in the field beyond just exploration. Suggestions for further reading, resources, or upcoming events related to AI in Pakistan could also enhance the call to action.
#
# Overall, while the blog provides a good overview of the topic, enhancing the depth of content, providing specific examples, and offering more actionable steps for readers could make it more engaging and impactful.
